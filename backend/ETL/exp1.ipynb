# %%
import pandas as pd

# %%
df = pd.read_csv("../dataset/train_data/train.csv")
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep
# 0            842     0          2.2         0   1       0           7    0.6  \
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time
# 0        188        2  ...         20       756  2549     9     7         19  \
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
dtype = [df[x].dtype.name for x in df.columns]
dtype_ = set(dtype)
print(dtype_)
cols = [x for x in df.columns]
mapping = {
    "int64": "INTEGER",
    "float64": "DECIMAL"
}
result = {}
for i in range(len(dtype)):
    result[cols[i]] = mapping[dtype[i]]
print(result)
# Out:
# {'float64', 'int64'}
# {'battery_power': 'INTEGER', 'blue': 'INTEGER', 'clock_speed': 'DECIMAL', 'dual_sim': 'INTEGER', 'fc': 'INTEGER', 'four_g': 'INTEGER', 'int_memory': 'INTEGER', 'm_dep': 'DECIMAL', 'mobile_wt': 'INTEGER', 'n_cores': 'INTEGER', 'pc': 'INTEGER', 'px_height': 'INTEGER', 'px_width': 'INTEGER', 'ram': 'INTEGER', 'sc_h': 'INTEGER', 'sc_w': 'INTEGER', 'talk_time': 'INTEGER', 'three_g': 'INTEGER', 'touch_screen': 'INTEGER', 'wifi': 'INTEGER', 'price_range': 'INTEGER'}

# %%
result
# Out:
# {'battery_power': 'INTEGER',
#  'blue': 'INTEGER',
#  'clock_speed': 'DECIMAL',
#  'dual_sim': 'INTEGER',
#  'fc': 'INTEGER',
#  'four_g': 'INTEGER',
#  'int_memory': 'INTEGER',
#  'm_dep': 'DECIMAL',
#  'mobile_wt': 'INTEGER',
#  'n_cores': 'INTEGER',
#  'pc': 'INTEGER',
#  'px_height': 'INTEGER',
#  'px_width': 'INTEGER',
#  'ram': 'INTEGER',
#  'sc_h': 'INTEGER',
#  'sc_w': 'INTEGER',
#  'talk_time': 'INTEGER',
#  'three_g': 'INTEGER',
#  'touch_screen': 'INTEGER',
#  'wifi': 'INTEGER',
#  'price_range': 'INTEGER'}

# %%
df["pk"] = df['battery_power']+df['blue']+df['clock_speed']+df['dual_sim']+df['fc']+df['four_g']+df['int_memory']+df['m_dep']+df['mobile_wt']+df['n_cores']+df['pc']+df['px_height']+df['px_width']+df['sc_w']+df['ram']+df['sc_h']+df['sc_w']+df['wifi']+df['talk_time']+df['three_g']+df['touch_screen']+df['wifi']
a = df["pk"].to_list()
s = set(a)
print(len(a), len(s))
# Out:
# 2000 1954

# %%
x = "+".join([f"df['{i}']" for i in df.columns])
x
# Out:
# "df['battery_power']+df['blue']+df['clock_speed']+df['dual_sim']+df['fc']+df['four_g']+df['int_memory']+df['m_dep']+df['mobile_wt']+df['n_cores']+df['pc']+df['px_height']+df['px_width']+df['ram']+df['sc_h']+df['sc_w']+df['talk_time']+df['three_g']+df['touch_screen']+df['wifi']+df['price_range']+df['pk']"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df["pk"]
# Out:
# 0       4413.8
# 1       6779.2
# 2       6374.4
# 3       6590.3
# 4       5898.8
#          ...
# 1995    4748.3
# 1996    7165.8
# 1997    7645.6
# 1998    3655.0
# 1999    5944.9
# Name: pk, Length: 2000, dtype: float64

# %%
import time
time.time()
# Out:
# 1685000759.2218914

# %%
from datetime import timezone
import datetime
  
  
# Getting the current date
# and time
dt = datetime.datetime.now(timezone.utc)
  
utc_time = dt.replace(tzinfo=timezone.utc)
utc_timestamp = utc_time.timestamp()
utc_timestamp_ = datetime.datetime.strftime(utc_time, '%d/%m/%Y %H:%M:%S')


a = datetime.datetime(utc_timestamp_)
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 14
#      10 utc_timestamp = utc_time.timestamp()
#      11 utc_timestamp_ = datetime.datetime.strftime(utc_time, '%d/%m/%Y %H:%M:%S')
# ---> 14 a = datetime.datetime(utc_timestamp_)
#      15 a
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
df.iloc[200:, :]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory
# 200            1703     1          0.5         0   0       1          22  \
# 201            1445     1          2.4         1   7       1          20
# 202            1087     0          1.3         0   0       1          16
# 203             671     0          0.9         1  10       0          30
# 204            1472     1          2.3         0   6       0          61
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time
# ...

# %%
l = list(df.columns)
len(l)
z = ""
x = ",".join([f"row.{i}" for i in df.columns])
x
# Out:
# 'row.battery_power,row.blue,row.clock_speed,row.dual_sim,row.fc,row.four_g,row.int_memory,row.m_dep,row.mobile_wt,row.n_cores,row.pc,row.px_height,row.px_width,row.ram,row.sc_h,row.sc_w,row.talk_time,row.three_g,row.touch_screen,row.wifi,row.price_range,row.pk'

# %%
[f"row.{i}" for i in df.columns][21]
# Out:
# 'row.pk'

# %%
data = pd.read_csv("../dataset/user_data/test.csv")
data.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory
# 0   1           1043     1          1.8         1  14       0           5  \
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w
# 0    0.1        193  ...  16        226      1412  3476    12     7  \
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
data["pk"] = data["battery_power"] + data["blue"] 
a = data["pk"].to_list()
s = set(a)
print(len(a), len(s))
# Out:
# 1000 740

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range', 'pk'],
#       dtype='object')

# %%
df["pk"] = df["px_height"]/df["px_width"] + df["ram"]
s = df["pk"].to_list()
a = set(s)
print(len(a), len(s))
df["pk"].dtype
# Out:
# 2000 2000
# dtype('float64')

# %%
df["pk"]
# Out:
# 0       2549.026455
# 1       2631.455231
# 2       2603.736014
# 3       2769.680851
# 4       1411.996700
#            ...
# 1995     668.646561
# 1996    2032.465649
# 1997    3057.531863
# 1998     869.501493
# 1999    3919.640584
# Name: pk, Length: 2000, dtype: float64
